# %%
#아래는 한글을 사용할 때 깨지는 문제에 대한 해결
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

#그래프의 축 등에서 음수를 표시할 때 minus sign이 깨지는 것 해결
import matplotlib as mpl
mpl.rcParams['axes.unicode_minus'] = False

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib inline

# %%
plt.title("plot 기본")

plt.plot([1, 4, 9, 16]) ## plot() 함수는 리스트의 값들이 y 값들이라고 가정하고 x 값[0, 1, 2, 3]등으로 지정 
plt.show()

# %%
plt.title("xplot 기본")

plt.plot([1, 2, 3, 4], [1, 4, 9, 16]) ## plot() 함수는 리스트의 값들이 y 값들이라고 가정하고 x 값[0, 1, 2, 3]등으로 지정 
plt.show()

# %%
plt.title("스타일 지정하기")

plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'gs') ## ro는 스타일 구글링을 통해 다양한 스타일 사용가능

plt.axis([0, 10, 0, 30])
#axis() 함수를 이용해서 축의 범위 [xmin, xmax, ymin, ymax] 지정
plt.show()

# %%
import numpy as np
plt.title("여러 개의 그래프 그리기")

t = np.arange(0., 5., 0.2)

plt.plot(t, t, "r--", t, t**2, "bs", t, t**3, "g^")
plt.show()

# %%
plt.title("딕셔너리 데이터 사용하기")

data_dict = {"data_x": [1, 2, 3, 4, 5], "data_y": [2, 3, 5, 10, 8]}
plt.plot("data_x", "data_y", "r--", data = data_dict) # 순서 중요
plt.axis([0, 6, 0, 12])

plt.show()

# %%
plt.title("축 레이블 설정")

plt.plot([1, 2, 3, 4], [1, 4, 16, 9])
plt.xlabel("x축")
plt.ylabel("y축")
plt.show()

# %%
plt.title("축 레이블 여백 설정")

plt.plot([1, 2, 3, 4], [1, 4, 16, 9])

plt.xlabel("x축", labelpad = 20)
plt.ylabel("y축", labelpad = 20)
plt.show()

# %%
plt.title("축 레이블 폰트 지정")

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('x축', labelpad=15, fontdict={'family': 'serif', 'color': 'b', 'weight': 'bold', 'size': 14})
plt.ylabel('y축', labelpad=20, fontdict={'family': 'fantasy', 'color': 'deeppink', 'weight': 'normal', 'size': 'xx-large'})
plt.show()
# Out:
# C:\Users\user\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 52629 (\N{HANGUL SYLLABLE CUG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
font1 = {'family': 'serif',
         'color': 'b',
         'weight': 'bold',
         'size': 14
         }

font2 = {'family': 'fantasy',
         'color': 'deeppink',
         'weight': 'normal',
         'size': 'xx-large'
         }

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis', labelpad=15, fontdict=font1)
plt.ylabel('Y-Axis', labelpad=50, fontdict=font2)
plt.show()

# %%
font1 = {'family': 'serif',
         'color': 'deeppink',
         'weight': 'bold',
         'size': 14
         }

font2 = {'family': 'fantasy',
         'color': 'b',
         'weight': 'normal',
         'size': 'xx-large'
         }
plt.title("범례 표시")
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label = "price ($)")
plt.xlabel('X-Axis', labelpad=15, fontdict=font1)
plt.ylabel('Y-Axis', labelpad=50, fontdict=font2)
plt.legend()
plt.show()

# %%
font1 = {'family': 'serif',
         'color': 'deeppink',
         'weight': 'bold',
         'size': 14
         }

font2 = {'family': 'fantasy',
         'color': 'b',
         'weight': 'normal',
         'size': 'xx-large'
         }
plt.title("범례 위치 지정1")
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label = "price ($)")
plt.xlabel('X-Axis', labelpad=15, fontdict=font1)
plt.ylabel('Y-Axis', labelpad=50, fontdict=font2)

# plt.legend(loc = (0.0, 0.0))
# plt.legend(loc = (0.5, 0.5))
# loc = (0.0, 0.0)은 데이터 영역의 왼쪽 아래, (1.0, 1.0)은 데이터 영역의 오른쪽
plt.legend(loc = (1.0, 1.0))
plt.show()

# %%
font1 = {'family': 'serif',
         'color': 'deeppink',
         'weight': 'bold',
         'size': 14
         }

font2 = {'family': 'fantasy',
         'color': 'b',
         'weight': 'normal',
         'size': 'xx-large'
         }
plt.title("범례 위치 지정1")
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label = "price ($)")
plt.plot([1, 2, 3, 4], [5, 7, 3, 8], label = "Demand (#)")
plt.xlabel('X-Axis', labelpad=15, fontdict=font1)
plt.ylabel('Y-Axis', labelpad=50, fontdict=font2)

# plt.legend(loc = (0.0, 0.0))
# plt.legend(loc = (0.5, 0.5))
# loc = (0.0, 0.0)은 데이터 영역의 왼쪽 아래, (1.0, 1.0)은 데이터 영역의 오른쪽
plt.legend(loc = "upper right", ncol = 1) # lower right, center 등이 있음
plt.show()

# %%
plt.title("범례 폰트 크기 지정")
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label = "price ($)")
plt.plot([1, 2, 3, 4], [5, 7, 3, 8], label = "Demand (#)")
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

plt.legend(loc = "best", ncol = 2, fontsize = 10) # 
plt.show()

# %%
plt.title("범례 폰트 크기 지정")
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label = "price ($)")
plt.plot([1, 2, 3, 4], [5, 7, 3, 8], label = "Demand (#)")
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

plt.legend(loc = "best", ncol = 2, fontsize = 10, frameon = True, shadow = True) # frameon을 False로 지정하면 테두리가 표시되지 않음
plt.show()

# %%
plt.title("축 범위 지정")
plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.xlim([0, 10])  # axis 대신 이것도 가능
plt.ylim([0, 20])

plt.show()

# %%
plt.title("축 범위 지정")
plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# plt.axis("normal")
plt.axis("on")
# # 'on' | 'off' | 'equal' | 'scaled' | 'tight' | 'auto' | 'normal' | 'image' | 'square'

plt.show()

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

x_range, y_range = plt.xlim(), plt.ylim()

print(x_range, y_range)

axis_range = plt.axis("square")

print(axis_range)

plt.show()
# Out:
# (0.85, 4.15) (1.6, 10.4)
# (0.85, 9.65, 1.6, 10.4)

# %%
# 선 종류 지정
#‘ - ‘ (Solid), ‘ - - ‘ (Dashed), ‘ : ‘ (Dotted), ‘ -. ‘ (Dash-dot)


plt.plot([1, 2, 3], [4, 4, 4], '-', color='C0', label='Solid')
plt.plot([1, 2, 3], [3, 3, 3], '--', color='C1', label='Dashed')
plt.plot([1, 2, 3], [2, 2, 2], ':', color='C2', label='Dotted')
plt.plot([1, 2, 3], [1, 1, 1], '-.', color='C3', label='Dash-dot')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0.8, 3.2, 0.5, 5.0])
plt.legend(loc='best', ncol=4, fontsize=8)
plt.show()

# %%
# 선 종류 지정
#‘ - ‘ (Solid), ‘ - - ‘ (Dashed), ‘ : ‘ (Dotted), ‘ -. ‘ (Dash-dot)


plt.plot([1, 2, 3], [4, 4, 4], linestyle = 'solid', color='C0', label='Solid')
plt.plot([1, 2, 3], [3, 3, 3], '--', color='C1', label='Dashed')
plt.plot([1, 2, 3], [2, 2, 2], ':', color='C2', label='Dotted')
plt.plot([1, 2, 3], [1, 1, 1], '-.', color='C3', label='Dash-dot')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0.8, 3.2, 0.5, 5.0])
plt.legend(loc='best', ncol=4, fontsize=8)
plt.show()

# %%
# 선 끝 모양 지정

plt.figure(figsize=(10, 6))
plt.plot([1, 2, 3], [4, 4, 4], linestyle='solid', linewidth=5,
      solid_capstyle='butt', color='r', label='solid+butt')
plt.plot([1, 2, 3], [3, 3, 3], linestyle='solid', linewidth=10,
      solid_capstyle='round', color='C0', label='solid+round')

plt.plot([1, 2, 3], [2, 2, 2], linestyle='dashed', linewidth=10,
      dash_capstyle='butt', color='C1', label='dashed+butt')
plt.plot([1, 2, 3], [1, 1, 1], linestyle='dashed', linewidth=10,
      dash_capstyle='round', color='C1', label='dashed+round')
# dash_capstyle를 사용해서 선의 끝 모양 지정
# {'butt', 'projecting', 'round'}

plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0.8, 3.2, 0.5, 5.0])
plt.legend(loc='upper right', ncol=2, fontsize=8)
plt.tight_layout()
plt.show()

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], "yo-.") # 파란색 + 마커 + 실선
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10], "b^:")  # 파란색 + 미카 + 점선

plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

plt.show()

# %%
# 다양한 마커 형태 지정

plt.plot([4, 5, 6], marker="H")
plt.plot([3, 4, 5], marker="d")
plt.plot([2, 3, 4], marker="x")
plt.plot([1, 2, 3], marker=11)
plt.plot([0, 1, 2], marker='$Z$')
plt.show()

# %%
plt.plot([4, 5, 6, 7], [5, 8, 12, 3], color = "aqua")
plt.show()

# %%
## Hex Color 찾기
plt.plot([4, 5, 6, 7], [5, 8, 12, 3], color = "#e37f32", marker = "v", linestyle = ":")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")

plt.show()

# %%
x = [1, 2, 3, 4,]
y = [2, 3, 5, 10]

plt.plot(x, y)
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.fill_between(x[1:3], y[1:3], alpha = 1) 
# (x[1], 0), (x[2], 0), (x[1], y[1]), (x[2], y[2])

plt.show()

# %%
x = [1, 2, 3, 4,]
y = [2, 3, 5, 10]

plt.plot(x, y)
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.fill_betweenx(y[2:4], x[2:4], alpha = 0.5) 
# (x[2], y[2]), (x[3], y[3]), (0, y[2]), (0, y[3])

plt.show()

# %%
x = [1, 2, 3, 4]
y1 = [2, 3, 5, 10]
y2 = [1, 2, 4, 8]

plt.plot(x, y1)
plt.plot(x, y2, color = "C3")
plt.xlabel("X축")
plt.ylabel("y축")
plt.fill_between(x[0:3], y1[0:3], y2[0:3], color = "green", alpha = 0.5)

plt.show()

# %%
# 다각형 영역 채우기 - fill()

x = [1, 2, 3, 4]
y1 = [2, 3, 5, 10]
y2 = [1, 2, 4, 8]

plt.plot(x, y1)
plt.plot(x, y2)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
#plt.fill([1.9, 1.9, 2.5], [1.0, 4.0, 6.0], color='gray', alpha=0.5)
plt.fill([2.0, 2.0, 2.5, 2.5], [2.0, 4.0, 4.0, 2.0], color='yellow', alpha=0.5)
# plt.fill(x,y)

plt.show()

# %%
# X축 스케일 지정

x = np.linspace(-10, 10, 100)
# linspace -10과 10 사이를 100개의 수로 채운 것
y = x ** 3

plt.plot(x, y)
plt.xscale('symlog') # linear log symlog
# Symmetrical Log Scale
#축의 원점을 기준으로 양, 음의 방향이 대칭적인 로그 스케일로 표시

plt.show()

# %%
#Y축 스케일 지정

x = np.linspace(0, 5, 100)
y = np.exp(x)

plt.plot(x, y)
#plt.yscale('linear')
plt.yscale('log')

plt.show()

# %%
# 그리드 설정

x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*')
plt.plot(x, x**3, color='springgreen', marker='^', markersize=9)
#plt.grid(True)
# plt.grid(True, axis='x')
# {‘both’, ‘x’, ‘y’} 중 선택할 수 있고 디폴트는 ‘both’
# plt.grid(True, axis='y', color='red', alpha=0.3, linestyle='-.')
plt.grid(True, color='red', alpha=0.3, linestyle='-.')

plt.show()

# %%
# 수평선/수직선 표시

x = np.arange(0, 4, 0.5)

plt.plot(x, x + 1, 'bo')
plt.plot(x, x**2 - 4, 'g--')
plt.plot(x, -2*x + 3, 'r:')

plt.axhline(4.0, 0.1, 0.9, color='lightgray', linestyle='--', linewidth=4)
# axhline(y값, xmin, xmax) /xmin, xmax는 0에서 1사이 값. 0은 왼쪽 끝, 1은 오른쪽 끝
plt.hlines(-0.62, 1.0, 2.5, color='gray', linestyle='solid', linewidth=3)
# hlines(y, xmin, xmax) / 점 (xmin, y)에서 점 (xmax, y)를 따라 수평선을 표시

plt.show()

# %%
# 수직선 그리기

x = np.arange(0, 4, 0.5)

plt.plot(x, x + 1, 'bo')
plt.plot(x, x**2 - 4, 'g--')
plt.plot(x, -2*x + 3, 'r:')

plt.axvline(1.0, 0.2, 0.8, color='lightgray', linestyle='--', linewidth=2)
# axvline(x 값, ymin, ymax) 
plt.vlines(1.8, -3.0, 2.0, color='gray', linestyle='solid', linewidth=3)
# vlines(x, ymin, ymax) / 점 (x, ymin)에서 점 (x, ymax)를 따라 수평선을 표시
plt.show()

# %%
x = np.arange(3)
years = ["2018", "2019", "2020"]
values = [100, 400, 900]

plt.bar(x, values)
plt.xticks(x, years)

plt.show()

# %%
x = np.arange(3)
years = ["2018", "2019", "2020"]
values = [100, 400, 900]
colors = ["y", "dodgerblue", "C2"]

plt.bar(x, values, color = colors)
plt.xticks(x, years)

plt.show()

# %%
x = np.arange(3)
years = ["2018", "2019", "2020"]
values = [100, 400, 900]
colors = ["y", "dodgerblue", "C2"]

plt.bar(x, values, color = colors, width = 0.4)
plt.xticks(x, years)

plt.show()

# %%
# 스타일 꾸미기

x = np.arange(3)
years = ['2018', '2019', '2020']
values = [100, 400, 900]

plt.bar(x, values, align='edge', edgecolor='lightgray',
        linewidth=5, tick_label=years, hatch='\\')
# {'/', '\\', '|', '-', '+', 'x', 'o', 'O', '.', '*'} 채우기 옵션

plt.show()

# %%
y = np.arange(3)
years = ['2018', '2019', '2020']
values = [100, 400, 900]

plt.barh(y, values, height = 0.4)
plt.yticks(y, years) #  Y축의 눈금 레이블에 ‘2018’, ‘2019’, ‘2020’이 순서대로 표시

plt.show()

# %%
np.random.seed()

n = 50
x = np.random.rand(n)
y = np.random.rand(n)

plt.scatter(x, y)
plt.show()
